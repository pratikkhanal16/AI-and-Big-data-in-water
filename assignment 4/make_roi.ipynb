# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
inp=np.load("data.npz")
imp=inp['arr_0']

# %%
print(imp.shape)
# Out:
# (669, 725, 8)

# %%
tab1=np.loadtxt('water.txt',delimiter=",")
print(tab1.shape)
# Out:
# (177, 2)

# %%
roi=np.zeros(shape=(669,725))
for i in range(tab1.shape[0]):
    roi[int(tab1[i,1]),int(tab1[i,0])]=1

# %%
plt.imshow(roi)
